# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy import stats
df=pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv",header=0)
df.head(10)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
# 5          2                122         audi        std          two
# 6          1                158         audi        std         four
# 7          1                122         audi        std         four
# 8          1                158         audi      turbo         four
# 9          2                192          bmw        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
numeric_df=df.select_dtypes(include=['float64','int64'])
numeric_df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
sns.regplot(x='engine-size',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 53374.91478384044)

# %%
sns.regplot(x=df['highway-mpg'],y=df['price'],data=df)
plt.ylim(0,)
# Out:
# (0.0, 48161.33032812769)

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
#Weak linear relationship
sns.regplot(x=df['peak-rpm'],y=df['price'],data=df)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
df.head(10)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
# 5          2                122         audi        std          two
# 6          1                158         audi        std         four
# 7          1                122         audi        std         four
# 8          1                158         audi      turbo         four
# 9          2                192          bmw        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# ...

# %%
df[['stroke','price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.regplot(x='stroke',y='price',data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
sns.boxplot(x='body-style',y='price',data=df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x=df['engine-location'],y=df['price'],data=df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %%
df['drive-wheels'].head(10)
# Out:
# 0    rwd
# 1    rwd
# 2    rwd
# 3    fwd
# 4    4wd
# 5    fwd
# 6    fwd
# 7    fwd
# 8    fwd
# 9    rwd
# Name: drive-wheels, dtype: object

# %%
sns.boxplot(x=df['drive-wheels'],y=df['price'],data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df['drive-wheels'].value_counts()
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
drive_wheels_counts=df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.reset_index(inplace=True)
drive_wheels_counts=drive_wheels_counts.rename(columns={'drive-wheels':'value_counts'})
drive_wheels_counts
# Out:
#   value_counts  count
# 0          fwd    118
# 1          rwd     75
# 2          4wd      8

# %%
drive_wheels_counts.index.name='drive-wheels'
drive_wheels_counts
# Out:
#              value_counts  count
# drive-wheels
# 0                     fwd    118
# 1                     rwd     75
# 2                     4wd      8

# %%
engine_location_counts=df['engine-location'].value_counts().to_frame()
engine_location_counts
# Out:
#                  count
# engine-location
# front              198
# rear                 3

# %%
engine_location_counts.reset_index(inplace=True)
engine_location_counts
# Out:
#    index engine-location  count
# 0      0           front    198
# 1      1            rear      3

# %%
engine_location_counts.index.name="engine-location-index"
engine_location_counts
# Out:
#                        index engine-location  count
# engine-location-index
# 0                          0           front    198
# 1                          1            rear      3

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one=df[['drive-wheels','body-style','price']]
df_grouped=df_group_one.groupby(['drive-wheels'],as_index=False).agg({'price':'mean'})
df_grouped
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
df_grouped_test=df_group_one.groupby(['drive-wheels','body-style'],as_index=False).mean({'price':'mean'})
df_grouped_test
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot=df_grouped_test.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot=grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
df_group=df[['body-style','price']]
df_group_new=df_group.groupby(['body-style'],as_index=False).mean({'price':'mean'})
df_group_new
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
plt.pcolor(grouped_pivot,cmap='RdBu')
plt.colorbar()
plt.show()

# %%
fig,ax=plt.subplots()
im=ax.pcolor(grouped_pivot,cmap='RdBu')
row_labels=grouped_pivot.columns.levels[1]
col_labels=grouped_pivot.index

ax.set_xticks(np.arange(grouped_pivot.shape[1])+0.5,minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0])+0.5,minor=False)

ax.set_xticklabels(row_labels,minor=False)
ax.set_yticklabels(col_labels,minor=False)

plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
df.head(10)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
# 5          2                122         audi        std          two
# 6          1                158         audi        std         four
# 7          1                122         audi        std         four
# 8          1                158         audi      turbo         four
# 9          2                192          bmw        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# ...

# %%
pearson_coeff,p_value=stats.pearsonr(df['wheel-base'],df['price'])
pearson_coeff
# Out:
# np.float64(0.5846418222655081)

# %%
p_value
# Out:
# np.float64(8.076488270732885e-20)

# %%
pearson_coeff1,p_value1=stats.pearsonr(df['horsepower'],df['price'])
print("The Pearson Correlation Coefficient is", pearson_coeff1, " with a P-value of P = ", p_value1)
# Out:
# The Pearson Correlation Coefficient is 0.809574567003656  with a P-value of P =  6.369057428259557e-48

# %%
pearson_coeff3,p_value3=stats.pearsonr(df['length'],df['price'])
print("The Pearson Correlation Coefficient is", pearson_coeff3, " with a P-value of P = ", p_value3)
# Out:
# The Pearson Correlation Coefficient is 0.690628380448364  with a P-value of P =  8.016477466158868e-30

# %%
pearson_coeff4,p_value4=stats.pearsonr(df['width'],df['price'])
print("The Pearson Correlation Coefficient is", pearson_coeff4, " with a P-value of P = ", p_value4)
# Out:
# The Pearson Correlation Coefficient is 0.7512653440522674  with a P-value of P =  9.20033551048144e-38

# %%
df.head(10)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
# 5          2                122         audi        std          two
# 6          1                158         audi        std         four
# 7          1                122         audi        std         four
# 8          1                158         audi      turbo         four
# 9          2                192          bmw        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm
# Out:
# LinearRegression()

# %%
x=df[['highway-mpg']]
y=df['price']
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(x)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %%
lm.intercept_
# Out:
# np.float64(38423.3058581574)

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %%
lm1=LinearRegression()
lm1
# Out:
# LinearRegression()

# %%
x=df[['engine-size']]
y=df['price']
lm1.fit(x,y)
# Out:
# LinearRegression()

# %%
Yhat=lm1.predict(x)
Yhat[0:5]
# Out:
# array([13728.4631336 , 13728.4631336 , 17399.38347881, 10224.40280408,
#        14729.62322775])

# %%
lm1.intercept_
# Out:
# np.float64(-7963.338906281046)

# %%
lm1.coef_
# Out:
# array([166.86001569])

# %%
sns.regplot(x=df['engine-size'],y=df['price'],data=df)
plt.ylim(0,)
# Out:
# (0.0, 53759.03747976042)

# %%
sns.residplot(x=df['engine-size'],y=df['price'],data=df)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
lm3=LinearRegression()
z=df[['horsepower','curb-weight','engine-size','highway-mpg']]
lm3.fit(z,df['price'])
# Out:
# LinearRegression()

# %%
lm3.intercept_
# Out:
# np.float64(-15806.624626329194)

# %%
lm3.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %%
#Multiple linear regression
lm4=LinearRegression()
y=df[['normalized-losses','highway-mpg']]
lm4.fit(y,df['price'])
lm4.intercept_
# Out:
# np.float64(38201.31327245728)

# %%
lm4.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %%
width=12
height=10
plt.figure(figsize=(width,height))
sns.regplot(x='highway-mpg',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 48186.088642769326)

# %%
width=12
height=10
plt.figure(figsize=(width,height))
sns.regplot(x='peak-rpm',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
df[['peak-rpm','highway-mpg']].corr()
# Out:
#              peak-rpm  highway-mpg
# peak-rpm     1.000000    -0.058598
# highway-mpg -0.058598     1.000000

# %%
pearson_coeff,p_value=stats.pearsonr(df['highway-mpg'],df['price'])
pearson_coeff
# Out:
# np.float64(-0.7046922650589529)

# %%
p_value
# Out:
# np.float64(1.7495471144476463e-31)

# %%
width=12
height=10
plt.figure(figsize=(width,height))
sns.residplot(x=df['highway-mpg'],y=df['price'],data=df)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
Y_hat=lm.predict(z)

# %%
plt.figure(figsize=(width,height))
ax1=sns.distplot(df['price'],hist=False,color="r",label="Actual Value")
sns.distplot(Y_hat,hist=False,color="b",label="Fitted Values",ax=ax1)
plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price(in dollars)')
plt.ylabel('Proportion of Cars')
plt.show()
plt.close()
# Out:
# C:\Users\Prasanth M\AppData\Local\Temp\ipykernel_5224\327150378.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df['price'],hist=False,color="r",label="Actual Value")
# C:\Users\Prasanth M\AppData\Local\Temp\ipykernel_5224\327150378.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
x=df['highway-mpg']
y=df['price']

# %%
f=np.polyfit(x,y,3)
p=np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
PlotPolly(p,x,y,'highway-mpg')

# %%
np.polyfit(x,y,3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %%
f1=np.polyfit(x,y,11)
p1=np.poly1d(f1)
print(p1)
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %%
PlotPolly(p1,x,y,'Highway-mpg')

# %%
from sklearn.preprocessing import PolynomialFeatures
pr=PolynomialFeatures(degree=2)
Z_pr=pr.fit_transform(z)

# %%
Z_pr
# Out:
# array([[1.0000e+00, 1.1100e+02, 2.5480e+03, ..., 1.6900e+04, 3.5100e+03,
#         7.2900e+02],
#        [1.0000e+00, 1.1100e+02, 2.5480e+03, ..., 1.6900e+04, 3.5100e+03,
#         7.2900e+02],
#        [1.0000e+00, 1.5400e+02, 2.8230e+03, ..., 2.3104e+04, 3.9520e+03,
#         6.7600e+02],
#        ...,
#        [1.0000e+00, 1.3400e+02, 3.0120e+03, ..., 2.9929e+04, 3.9790e+03,
#         5.2900e+02],
#        [1.0000e+00, 1.0600e+02, 3.2170e+03, ..., 2.1025e+04, 3.9150e+03,
#         7.2900e+02],
#        [1.0000e+00, 1.1400e+02, 3.0620e+03, ..., 1.9881e+04, 3.5250e+03,
#         6.2500e+02]], shape=(201, 15))

# %%
z.shape
# Out:
# (201, 4)

# %%
Z_pr.shape
# Out:
# (201, 15)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()),('polynomial',PolynomialFeatures(include_bias=False)),('model',LinearRegression())]
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
z=z.astype(float)
pipe.fit(z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
ypipe=pipe.predict(z)
ypipe[0:4]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555])

# %%
input1=[('scale',StandardScaler()),('model',LinearRegression())]
pipe=Pipeline(input1)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('model', LinearRegression())])

# %%
pipe.fit(z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('model', LinearRegression())])

# %%
ypipe=pipe.predict(z)
ypipe[0:10]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097])

# %%
x=df[['highway-mpg']]
y=df['price']
lm.fit(x,y)
print("The R-square is: ",lm.score(x,y))
# Out:
# The R-square is:  0.4965911884339176

# %%
Yhat=lm.predict(x)
print('The output of the first four predicted value is: ',Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(df['price'],Yhat)
print("The mean squared error of the price and the predicted value is: ",mse)
# Out:
# The mean squared error of the price and the predicted value is:  31635042.944639888

# %%
new_input=np.arange(1,100,1).reshape(-1,1)
lm.fit(x,y)
lm
# Out:
# LinearRegression()

# %%
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# c:\Users\Prasanth M\anaconda3\envs\muruga\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655])

# %%
plt.plot(new_input,yhat)
plt.show()
